# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
lung_cancer = "Resources/survey_lung_cancer_rawdata.csv"


# Read the  Data and  store into a Pandas DataFrame
lung_cancer_df = pd.read_csv(lung_cancer)

lung_cancer_df.tail(10)
# Out:
#     GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 299      M   65     YES            YES     YES           YES              NO
# 300      F   63     YES            YES     YES           YES             YES
# 301      M   64      NO            YES     YES           YES              NO
# 302      F   65     YES            YES     YES           YES              NO
# 303      M   51      NO            YES      NO            NO             YES
# 304      F   56      NO             NO      NO           YES             YES
# 305      M   70     YES             NO      NO            NO              NO
# 306      M   58     YES             NO      NO            NO              NO
# 307      M   67     YES             NO     YES            NO              NO
# 308      M   62      NO             NO      NO           YES              NO
#
#     FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
lung_cancer = "Resources/survey lung cancer.csv"


# Read the  Data and  store into a Pandas DataFrame
lung_cancer_df = pd.read_csv(lung_cancer)

lung_cancer_df.tail(10)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 299      M   65        2               2        2              2
# 300      F   63        2               2        2              2
# 301      M   64        1               2        2              2
# 302      F   65        2               2        2              2
# 303      M   51        1               2        1              1
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 299                1         2         2         1                  1
# 300                2         2         2         2                  1
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
total_cancer_death = "Resources/total-cancer-deaths-by-type.csv"


# Read the  Data and  store into a Pandas DataFrame
total_cancer_death_df = pd.read_csv(total_cancer_death)

total_cancer_death_df.tail(10)
# Out:
#         Entity Code  Year  \
# 8000  Zimbabwe  ZWE  2010
# 8001  Zimbabwe  ZWE  2011
# 8002  Zimbabwe  ZWE  2012
# 8003  Zimbabwe  ZWE  2013
# 8004  Zimbabwe  ZWE  2014
# 8005  Zimbabwe  ZWE  2015
# 8006  Zimbabwe  ZWE  2016
# 8007  Zimbabwe  ZWE  2017
# 8008  Zimbabwe  ZWE  2018
# 8009  Zimbabwe  ZWE  2019
#
#       Deaths - Liver cancer - Sex: Both - Age: All Ages (Number)  \
# 8000                                                929
# 8001                                                919
# 8002                                                916
# 8003                                                917
# 8004                                                931
# 8005                                                948
# 8006                                                966
# 8007                                                982
# 8008                                                998
# 8009                                               1016
#
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
lung_cancer_examples = "Resources/lung_cancer_examples.csv"


# Read the  Data and  store into a Pandas DataFrame
lung_cancer_examples_df = pd.read_csv(lung_cancer_examples)

lung_cancer_examples_df.tail(10)
# Out:
#           Name    Surname  Age  Smokes  AreaQ  Alkhol  Result
# 49  Katharine     Hepburn   62      20      5       6       1
# 50  Katharine     Hepburn   42      12      6       2       0
# 51     Barbra   Streisand   44      30      1       6       1
# 52     Maggie       Smith   26      34      1       8       1
# 53     Glenda     Jackson   35      20      5       1       0
# 54     Ernest    Borgnine   26      13      6       1       0
# 55       Alec    Guinness   77      20      5       4       1
# 56   Charlton      Heston   75      15      3       5       1
# 57    Gregory        Peck   43      30      3       8       1
# 58     Sidney     Poitier   51      25      9       0       0

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
Lung_Bronchus_Cancer_NYC = "Resources/Lung and Bronchus Cancer_NYC.csv"

# %%
# Read the  Data and  store into a Pandas DataFrame
Lung_Bronchus_Cancer_NYC_df = pd.read_csv(Lung_Bronchus_Cancer_NYC, skiprows = 7)

Lung_Bronchus_Cancer_NYC_df
# Out:
#                                             2011-2015  \
# 0                                           2011-2015
# 1                                           2011-2015
# 2                                           2011-2015
# 3                                           2011-2015
# 4                                           2011-2015
# ..                                                ...
# 65                      Name:Lung and Bronchus Cancer
# 66        NYC Department of Health and Mental Hygiene
# 67                   Environment & Health Data Portal
# 68  More information can be found at: http://nyc.g...
# 69                                Accessed 05/04/2022
#
#                                           Citywide  \
# 0                                          Borough
# 1                                          Borough
# 2                                          Borough
# 3                                          Borough
# 4                                          Borough
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
Provisional_Cancer_Death = "Resources/AH_Provisional_Cancer_Death_Counts_by_Month_and_Year__2020-2021.csv"


# Read the  Data and  store into a Pandas DataFrame
Provisional_Cancer_Death_df = pd.read_csv(Provisional_Cancer_Death)

Provisional_Cancer_Death_df.tail(10)
# Out:
#       Data As Of  Start Date    End Date        Country  Year  Month  \
# 2806  11/23/2021  01/01/2021  01/31/2021  United States  2021      1
# 2807  11/23/2021  02/01/2021  02/28/2021  United States  2021      2
# 2808  11/23/2021  03/01/2021  03/31/2021  United States  2021      3
# 2809  11/23/2021  04/01/2021  04/30/2021  United States  2021      4
# 2810  11/23/2021  05/01/2021  05/31/2021  United States  2021      5
# 2811  11/23/2021  06/01/2021  06/30/2021  United States  2021      6
# 2812  11/23/2021  07/01/2021  07/31/2021  United States  2021      7
# 2813  11/23/2021  08/01/2021  08/31/2021  United States  2021      8
# 2814  11/23/2021  09/01/2021  09/30/2021  United States  2021      9
# 2815  11/23/2021  10/01/2021  10/31/2021  United States  2021     10
#
#            Sex          Age Group Race and Hispanic Origin  \
# 2806  Male (M)  75 years and over                  Unknown
# 2807  Male (M)  75 years and over                  Unknown
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
cancer_patients_data_sets = "Resources/cancer patient data sets.csv"


# Read the  Data and  store into a Pandas DataFrame
cancer_patients_data_sets_df = pd.read_csv(cancer_patients_data_sets)

cancer_patients_data_sets_df.tail(10)
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 990       P990   49       1              6            5             6
# 991       P991   37       1              8            8             7
# 992       P992   26       2              7            7             7
# 993       P993   37       2              7            7             7
# 994       P994   33       1              6            7             7
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 990                     5             5                     4              6
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
Cancer_Atlas = "Resources/Cancer-Atlas-3rd-ed_Map-data.csv"


# Read the  Data and  store into a Pandas DataFrame
Cancer_Atlas_df = pd.read_csv(Cancer_Atlas, engine='python')
Cancer_Atlas_df.tail(10)
# Out:
#     Country or Territory ISO 3 code  \
# 204            Greenland        GRL
# 205             Holy See        VAT
# 206              R�union        REU
# 207     French Polynesia        PYF
# 208           Guadeloupe        GLP
# 209                 Guam        GUM
# 210           Martinique        MTQ
# 211                  NaN        NaN
# 212                  NaN        NaN
# 213                  NaN        NaN
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 204                                            No data
# 205                                            No data
# 206                                            No data
# 207                                            No data
# 208                                            No data
# 209                                            No data
# 210                                            No data
# ...

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
ACPs_Breast_cancer = "Resources/ACPs_Breast_cancer.csv"


# Read the  Data and  store into a Pandas DataFrame
ACPs_Breast_cancer_df = pd.read_csv(ACPs_Breast_cancer)

ACPs_Breast_cancer_df.tail(10)
# Out:
#       ID                 sequence               class
# 939  940             YFSKGIPNVLRR  inactive - virtual
# 940  941          YGSIGLTNFGYLDKE  inactive - virtual
# 941  942         YKEPLKAVVKKLLEKE  inactive - virtual
# 942  943              YKKFRQLIQVN  inactive - virtual
# 943  944      YLADLFLAPQIHGAINRFQ  inactive - virtual
# 944  945  YLDKEVKLIKKMGNHLTNLRRVA  inactive - virtual
# 945  946  YLSESVETIKKLGDHITSLKKLW  inactive - virtual
# 946  947          YPIVDAAMRQLTETG  inactive - virtual
# 947  948         YQNIVKAVQYAARKLQ  inactive - virtual
# 948  949            YQQQKKYLGRMTE  inactive - virtual

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
ACPs_lung_cancer = "Resources/ACPs_lung_cancer.csv"


# Read the  Data and  store into a Pandas DataFrame
ACPs_lung_cancer_df = pd.read_csv(ACPs_lung_cancer)

ACPs_lung_cancer_df.tail(10)
# Out:
#       ID                 sequence               class
# 891  892             YFSKGIPNVLRR  inactive - virtual
# 892  893          YGSIGLTNFGYLDKE  inactive - virtual
# 893  894         YKEPLKAVVKKLLEKE  inactive - virtual
# 894  895              YKKFRQLIQVN  inactive - virtual
# 895  896      YLADLFLAPQIHGAINRFQ  inactive - virtual
# 896  897  YLDKEVKLIKKMGNHLTNLRRVA  inactive - virtual
# 897  898  YLSESVETIKKLGDHITSLKKLW  inactive - virtual
# 898  899          YPIVDAAMRQLTETG  inactive - virtual
# 899  900         YQNIVKAVQYAARKLQ  inactive - virtual
# 900  901            YQQQKKYLGRMTE  inactive - virtual
