# %%
# Import dependencies and load in CSV files
import pandas as pd
from pathlib import Path 

nyc_inspection_df = pd.read_csv("Resources/nyc_restaurants/DOHMH_New_York_City_Restaurant_Inspection_Results.csv") # , index_col=0)
nyc_income_df = pd.read_csv("Resources/nyc_restaurants/Pre_restaurants.csv") #, index_col=0)

# %%
# Read the df from the NYC restaurant inspections
nyc_inspection_df.head(5)
# Out:
#       CAMIS                      DBA           BORO BUILDING         STREET  \
# 0  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 1  40511702        NOTARO RESTAURANT      MANHATTAN      635  SECOND AVENUE
# 2  50046354                 VITE BAR         QUEENS     2507       BROADWAY
# 3  50061389  TACK'S CHINESE TAKE OUT  STATEN ISLAND      11C    HOLDEN BLVD
# 4  41516263               NO QUARTER       BROOKLYN     8015       5 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  10016.0  2126863400             Italian      06/15/2015
# 1  10016.0  2126863400             Italian      11/25/2014
# 2  11106.0  3478134702             Italian      10/03/2016
# 3  10314.0  7189839854             Chinese      05/17/2017
# 4  11209.0  7187019180            American      03/30/2017
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1  Violations were cited in the following area(s).            20F
# 2  Violations were cited in the following area(s).            10F
# 3  Violations were cited in the following area(s).            02G
# 4  Violations were cited in the following area(s).            04M
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0        Hot food item not held at or above 140Âº F.      Critical   30.0
# 1              Current letter grade card not posted.  Not Critical    NaN
# 2  Non-food contact surface improperly constructe...  Not Critical    2.0
# 3  Cold food item held above 41Âº F (smoked fish ...      Critical   46.0
# 4  Live roaches present in facility's food and/or...      Critical   18.0
#
#   GRADE GRADE DATE RECORD DATE  \
# 0   NaN        NaN  08/28/2017
# 1   NaN        NaN  08/28/2017
# 2   NaN        NaN  08/28/2017
# 3   NaN        NaN  08/28/2017
# 4   NaN        NaN  08/28/2017
#
#                                      INSPECTION TYPE
# 0              Cycle Inspection / Initial Inspection
# 1  Administrative Miscellaneous / Initial Inspection
# 2      Pre-permit (Operational) / Initial Inspection
# 3      Pre-permit (Operational) / Initial Inspection
# 4              Cycle Inspection / Initial Inspection

# %%
# Read the df from the income levels of the areas around the restaurants
nyc_income_df.head(5)
# Out:
#    Unnamed: 0  New York    Borough  income_num_returns(households)  \
# 0           0     10007  Manhattan                            3640
# 1           1     10007  Manhattan                            3640
# 2           2     10007  Manhattan                            3640
# 3           4     10007  Manhattan                            3640
# 4           5     10007  Manhattan                            3640
#
#    avg income per return(x1000s) income level  \
# 0                     693.379945  high income
# 1                     693.379945  high income
# 2                     693.379945  high income
# 3                     693.379945  high income
# 4                     693.379945  high income
#
#                                DBA            STREET  GRADE DATE   LATITUDE  \
# 0            MARIACHI'S RESTAURANT   CHAMBERS STREET   1/13/2020  40.716432
# 1            SPOTIFY - BARISTA BAR  GREENWICH STREET   1/22/2020  40.715553
# 2  STARBUCKS COFFEE COMPANY #29854  GREENWICH STREET   1/13/2020  40.715553
# 3                          CANTEEN   WORLD TRADE CTR   1/23/2020  40.713941
# 4     JOE & THE JUICE GREENWICH ST  GREENWICH STREET  12/30/2019  40.715553
#
#    LONGITUDE
# 0 -74.010472
# 1 -74.011021
# 2 -74.011021
# 3 -74.007401
# 4 -74.011021

# %%
# Drop columns
clean_inspection_df = nyc_inspection_df.drop(['CAMIS', 'BUILDING', 'ZIPCODE', 'PHONE', 'INSPECTION DATE', 
                                              'ACTION', 'VIOLATION CODE', 'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 
                                              'RECORD DATE', 'INSPECTION TYPE'], axis=1)

# %%
# Check cleaned dataframe
clean_inspection_df.head()
# Out:
#                        DBA           BORO         STREET CUISINE DESCRIPTION  \
# 0        NOTARO RESTAURANT      MANHATTAN  SECOND AVENUE             Italian
# 1        NOTARO RESTAURANT      MANHATTAN  SECOND AVENUE             Italian
# 2                 VITE BAR         QUEENS       BROADWAY             Italian
# 3  TACK'S CHINESE TAKE OUT  STATEN ISLAND    HOLDEN BLVD             Chinese
# 4               NO QUARTER       BROOKLYN       5 AVENUE            American
#
#    SCORE GRADE GRADE DATE
# 0   30.0   NaN        NaN
# 1    NaN   NaN        NaN
# 2    2.0   NaN        NaN
# 3   46.0   NaN        NaN
# 4   18.0   NaN        NaN

# %%
# Change column name to match the other dataset
clean_inspection_df.rename(columns = {'BORO':'Borough'}, inplace = True)

# %%
# Drop null values
clean_inspection_df2 = clean_inspection_df.dropna()

# %%
# Check new df with no null values
clean_inspection_df2.head()
# Out:
#                              DBA        Borough               STREET  \
# 6               HENRI'S BACKYARD       BROOKLYN              4TH AVE
# 7   RICHMOND COUNTY COUNTRY CLUB  STATEN ISLAND       TODT HILL ROAD
# 9                    TOMOE SUSHI      MANHATTAN      THOMPSON STREET
# 12          CRAB SPOT RESTAURANT       BROOKLYN         UNION STREET
# 13                 M NOODLE SHOP       BROOKLYN  METROPOLITAN AVENUE
#
#    CUISINE DESCRIPTION  SCORE GRADE  GRADE DATE
# 6             American   39.0     C  06/22/2017
# 7             American   12.0     A  06/14/2017
# 9             Japanese   13.0     A  10/06/2015
# 12             Seafood   12.0     A  07/28/2016
# 13             Chinese   10.0     A  01/19/2017

# %%
# Check if we dropped all null values
clean_inspection_df2.isnull().sum()
# Out:
# DBA                    0
# Borough                0
# STREET                 0
# CUISINE DESCRIPTION    0
# SCORE                  0
# GRADE                  0
# GRADE DATE             0
# dtype: int64

# %%
# Drop columns
clean_income_df = nyc_income_df.drop(['Unnamed: 0', 'New York', 'income_num_returns(households)', 
                                      'avg income per return(x1000s)'], axis=1)

# %%
# Rename to all capital for consistent column names
clean_income_df.rename(columns = {'income level':'INCOME LEVEL'}, inplace = True)

# %%
# Check cleaned up df
clean_income_df.head()
# Out:
#      Borough INCOME LEVEL                              DBA            STREET  \
# 0  Manhattan  high income            MARIACHI'S RESTAURANT   CHAMBERS STREET
# 1  Manhattan  high income            SPOTIFY - BARISTA BAR  GREENWICH STREET
# 2  Manhattan  high income  STARBUCKS COFFEE COMPANY #29854  GREENWICH STREET
# 3  Manhattan  high income                          CANTEEN   WORLD TRADE CTR
# 4  Manhattan  high income     JOE & THE JUICE GREENWICH ST  GREENWICH STREET
#
#    GRADE DATE   LATITUDE  LONGITUDE
# 0   1/13/2020  40.716432 -74.010472
# 1   1/22/2020  40.715553 -74.011021
# 2   1/13/2020  40.715553 -74.011021
# 3   1/23/2020  40.713941 -74.007401
# 4  12/30/2019  40.715553 -74.011021

# %%
# Check for null values
clean_income_df.isnull().sum()
# Out:
# Borough         0
# INCOME LEVEL    0
# DBA             0
# STREET          0
# GRADE DATE      0
# LATITUDE        0
# LONGITUDE       0
# dtype: int64

# %%
# Exporting df as new CSV file
clean_inspection_df2.to_csv('Resources/clean_inspection_df2.csv', index = False)

# %%
# Exporting df as new CSV file
clean_income_df.to_csv('Resources/clean_income_df.csv', index = False)

# %%
# Drop columns for the purpose of joining cleanly on postgress
clean_income_df2 = clean_income_df.drop(['Borough', 'GRADE DATE', 'LATITUDE', 'LONGITUDE'], axis=1)

# %%
clean_income_df2.head()
# Out:
#   INCOME LEVEL                              DBA            STREET
# 0  high income            MARIACHI'S RESTAURANT   CHAMBERS STREET
# 1  high income            SPOTIFY - BARISTA BAR  GREENWICH STREET
# 2  high income  STARBUCKS COFFEE COMPANY #29854  GREENWICH STREET
# 3  high income                          CANTEEN   WORLD TRADE CTR
# 4  high income     JOE & THE JUICE GREENWICH ST  GREENWICH STREET

# %%
# Exporting df as new CSV file
clean_income_df2.to_csv('Resources/clean_income_df2.csv', index = False)

# %%
# See how datasets look when joined
joined_inspection_df = pd.merge(clean_inspection_df2, clean_income_df2, how='left', on=["STREET", "DBA"])
joined_inspection_df.head(100)
# Out:
#                                       DBA        Borough  \
# 0                        HENRI'S BACKYARD       BROOKLYN
# 1            RICHMOND COUNTY COUNTRY CLUB  STATEN ISLAND
# 2                             TOMOE SUSHI      MANHATTAN
# 3                    CRAB SPOT RESTAURANT       BROOKLYN
# 4                           M NOODLE SHOP       BROOKLYN
# ..                                    ...            ...
# 95                                MR TONG       BROOKLYN
# 96             ELEGANT CHINESE RESTAURANT         QUEENS
# 97                        EAST 86 CINEMAS      MANHATTAN
# 98  GOLDEN KRUST CARIBBEAN BAKERY & GRILL       BROOKLYN
# 99                              VB BAKERY         QUEENS
#
#                    STREET CUISINE DESCRIPTION  SCORE GRADE  GRADE DATE  \
# 0                 4TH AVE            American   39.0     C  06/22/2017
# 1          TODT HILL ROAD            American   12.0     A  06/14/2017
# 2         THOMPSON STREET            Japanese   13.0     A  10/06/2015
# 3            UNION STREET             Seafood   12.0     A  07/28/2016
# 4     METROPOLITAN AVENUE             Chinese   10.0     A  01/19/2017
# ..                    ...                 ...    ...   ...         ...
# 95  FORT HAMILTON PARKWAY             Chinese   10.0     A  09/11/2014
# 96        HILLSIDE AVENUE             Chinese    9.0     A  05/20/2015
# 97       EAST   86 STREET            American    7.0     A  09/08/2015
# 98        FLATBUSH AVENUE           Caribbean   11.0     P  09/09/2016
# 99                97TH ST              Bakery    9.0     A  05/04/2017
#
#    INCOME LEVEL
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 8 columns]

# %%
joined_inspection_df.tail(100)
# Out:
#                               DBA        Borough                 STREET  \
# 208063               AMBROSE HALL      MANHATTAN              FULTON ST
# 208064         UNTAMED SANDWICHES      MANHATTAN              W 39TH ST
# 208065              CANTON LOUNGE      MANHATTAN                MOTT ST
# 208066               TORINO PIZZA  STATEN ISLAND          RICHMOND ROAD
# 208067    CARIBBEAN STYLE CUISINE         QUEENS     ROCKAWAY BOULEVARD
# ...                           ...            ...                    ...
# 208158       RICHNESS  RESTAURANT       BROOKLYN             RUTLAND RD
# 208159             DUNKIN' DONUTS         QUEENS  GRAND CENTRAL PARKWAY
# 208160              MAGGIES PLACE      MANHATTAN       EAST   47 STREET
# 208161  RUBY FALLS NIGHTLIFE CAFE  STATEN ISLAND            PAGE AVENUE
# 208162             DUNKIN' DONUTS       BROOKLYN            NEPTUNE AVE
#
#        CUISINE DESCRIPTION  SCORE GRADE  GRADE DATE INCOME LEVEL
# 208063             Seafood    9.0     A  05/13/2015          NaN
# 208064            American   11.0     A  06/22/2016          NaN
# 208065             Chinese    2.0     C  12/23/2015          NaN
# 208066       Pizza/Italian   22.0     Z  01/19/2017          NaN
# 208067           Caribbean   24.0     B  12/11/2013          NaN
# ...                    ...    ...   ...         ...          ...
# 208158           Caribbean   11.0     A  03/14/2016          NaN
# 208159              Donuts    9.0     A  05/02/2017          NaN
# 208160            American   11.0     A  02/29/2016  high income
# 208161            American   12.0     A  09/19/2014          NaN
# 208162              Donuts    9.0     A  11/15/2016          NaN
#
# [100 rows x 8 columns]

# %%
joined_inspection_df2 = joined_inspection_df.dropna()
joined_inspection_df2.tail()
# Out:
#                   DBA    Borough            STREET CUISINE DESCRIPTION  SCORE  \
# 208153         SUBWAY  MANHATTAN          3 AVENUE          Sandwiches   13.0
# 208154         SUBWAY  MANHATTAN          3 AVENUE          Sandwiches   13.0
# 208155         SUBWAY  MANHATTAN          3 AVENUE          Sandwiches   13.0
# 208156      STARBUCKS  MANHATTAN       YORK AVENUE    CafÃ©/Coffee/Tea    9.0
# 208160  MAGGIES PLACE  MANHATTAN  EAST   47 STREET            American   11.0
#
#        GRADE  GRADE DATE INCOME LEVEL
# 208153     A  01/16/2015  high income
# 208154     A  01/16/2015  high income
# 208155     A  01/16/2015  high income
# 208156     A  12/01/2014  high income
# 208160     A  02/29/2016  high income

# %%
joined_inspection_df3 = joined_inspection_df2.drop_duplicates()

# %%
joined_inspection_df3.head(10)
# Out:
#                                         DBA    Borough              STREET  \
# 10   TROPICAL REVIVAL RESTAURANT & CATERING     QUEENS     CLINTONVILLE ST
# 15                            WOLF AND LAMB  MANHATTAN    EAST   48 STREET
# 24                BROOK AVENUE DELI & PIZZA      BRONX        BROOK AVENUE
# 32                PLAZA TULCINGO RESTAURANT      BRONX   EAST CLARKE PLACE
# 49         GOOD ENOUGH TO EAT (A.G. BISTRO)  MANHATTAN     COLUMBUS AVENUE
# 76                               BAREBURGER     QUEENS         VERNON BLVD
# 78                  PANCHO VILLA RESTAURANT      BRONX       JEROME AVENUE
# 102                                 GIRELLO  MANHATTAN  NORTH MOORE STREET
# 108                        DOCKS RESTAURANT  MANHATTAN            3 AVENUE
# 123                          CAFE CORTADITO  MANHATTAN    EAST    3 STREET
#
#                                    CUISINE DESCRIPTION  SCORE GRADE  \
# 10                                           Caribbean    2.0     A
# 15                                               Steak   12.0     A
# 24                                               Pizza   12.0     A
# 32                                             Mexican   33.0     C
# 49                                            American   33.0     C
# 76                                          Hamburgers   10.0     A
# 78                                             Mexican   42.0     C
# 102                                            Italian   12.0     A
# 108                                            Seafood    9.0     A
# 123  Latin (Cuban, Dominican, Puerto Rican, South &...   11.0     A
#
#      GRADE DATE   INCOME LEVEL
# 10   11/15/2016  medium income
# 15   12/16/2014    high income
# 24   08/02/2017     low income
# 32   09/08/2016     low income
# 49   01/30/2015    high income
# 76   03/25/2015  medium income
# 78   12/01/2016     low income
# 102  03/04/2015    high income
# 108  09/02/2014    high income
# 123  09/29/2015  medium income

# %%
joined_inspection_df3.to_csv('Resources/joined_inspection_df3.csv', index = False)
